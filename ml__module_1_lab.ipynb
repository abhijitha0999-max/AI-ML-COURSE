# %% [markdown]
# <a href="https://colab.research.google.com/github/abhijitha0999-max/AI-ML-COURSE/blob/main/ml__module_1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Matrix Operations
#
# ## Print outputs in python
#
# Use the `print()` command to display content of a variable in python. For example a message 'Hello Python' can be displayed as:

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Displaying output of a variable and operation in python as follows:

# %%
a=2
b=5
print("Value of a:", a)
print("Value of b: ", b)
print("Value of the operation, a+(2b) is:",a+(2*b))
# Out:
# Value of a: 2
# Value of b:  5
# Value of the operation, a+(2b) is: 12

# %% [markdown]
# ## Reading a value to a variable in python
# Use the funtion `input()`. For example :

# %%
v=input("Enter the value:")
print(" The value read is:", v)
# Out:
# Enter the value:23
#  The value read is: 23

# %% [markdown]
# ## Reading a vector in `python`

# %%
import numpy as np
v1=np.array([1,2,3])
v2=np.array([2,4,5])
a=2.3
print("The vector is: {}".format(v1))
print('The scalar product of {}  with {} is : {}'.format(v1,a,a*v1))
print('The linear combination of {} and {} is :{}'.format(v1,v2,a*v1+v2))
# Out:
# The vector is: [1 2 3]
# The scalar product of [1 2 3]  with 2.3 is : [2.3 4.6 6.9]
# The linear combination of [1 2 3] and [2 4 5] is :[ 4.3  8.6 11.9]

# %% [markdown]
# ## Matrix operations in `python`

# %%
M1=np.array([[1,2,3],[2,3,4],[4,5,6]])
M2=np.array([[3,2,1],[2,4,6],[5,6,7]])
print('Sum of matrices:\n',M1+M2)
print('Scalar product:\n',a*M1)
print('Element-wise product:\n',M1*M2)
print('Matrix Product\n',np.dot(M1,M2))
# Out:
# Sum of matrices:
#  [[ 4  4  4]
#  [ 4  7 10]
#  [ 9 11 13]]
# Scalar product:
#  [[ 2.3  4.6  6.9]
#  [ 4.6  6.9  9.2]
#  [ 9.2 11.5 13.8]]
# Element-wise product:
#  [[ 3  4  3]
#  [ 4 12 24]
#  [20 30 42]]
# Matrix Product
#  [[22 28 34]
#  [32 40 48]
#  [52 64 76]]

# %%
print('The matrices are:M1 is:\n {} and M2 is\n {}'.format(M1,M2))
print('Outer Product:\n',np.outer(M1,M2))
print('Kronecker product:\n',np.kron(M1,M2))
# Out:
# The matrices are:M1 is:
#  [[1 2 3]
#  [2 3 4]
#  [4 5 6]] and M2 is
#  [[3 2 1]
#  [2 4 6]
#  [5 6 7]]
# Outer Product:
#  [[ 3  2  1  2  4  6  5  6  7]
#  [ 6  4  2  4  8 12 10 12 14]
#  [ 9  6  3  6 12 18 15 18 21]
#  [ 6  4  2  4  8 12 10 12 14]
#  [ 9  6  3  6 12 18 15 18 21]
#  [12  8  4  8 16 24 20 24 28]
#  [12  8  4  8 16 24 20 24 28]
#  [15 10  5 10 20 30 25 30 35]
#  [18 12  6 12 24 36 30 36 42]]
# Kronecker product:
#  [[ 3  2  1  6  4  2  9  6  3]
#  [ 2  4  6  4  8 12  6 12 18]
#  [ 5  6  7 10 12 14 15 18 21]
#  [ 6  4  2  9  6  3 12  8  4]
#  [ 4  8 12  6 12 18  8 16 24]
#  [10 12 14 15 18 21 20 24 28]
#  [12  8  4 15 10  5 18 12  6]
#  [ 8 16 24 10 20 30 12 24 36]
#  [20 24 28 25 30 35 30 36 42]]
